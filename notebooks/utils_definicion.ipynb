# %% [markdown]
# ## amazon_books.ipynb
#
# En este archivo se ha abierto la bbdd en excel de los 100 libros más vendidos en amazon para el rango de años de 2009 a 2021
#
# También se ha probado a limpiar el libro. Parte de esa limpieza ha pasado al archivo amazon100paper.py
#
# Se han descartado de incluir en el archivo py el crear columnas por año. De momento aunque hay libros repetidos en el dataset, vamos a ver cómo lo trabajamos con el resto de bbdd
#
# ## amazon100paper.py
#
# Código en python con el resumen del archivo anterior. Actualmente este sería el archivo a **utilizar** cuando queramos sacar la tabla de datos limpia a utilizar para posteriores análisis
#
# ## bd_kindle.ipynb
#
# Borrador para el procesamiento de la bbdd de kindle. En el se ha generado el código previo a inclu9ir en el archivo python: kindle_clean.py
#
# ## kindle_clean.py
#
# Este archivo es el que contiene el código para la limpieza de la bbdd de los libros en formato kindle. En él se ha incluido un ranking general según el número de reviews y posteriormente se han incluido rankings por categoría dejando solo los 100 libros con más reviews por categoría.
#
# ## ws_bookfilm.py
#
# Código del web scraping para obtener las mejores adaptaciones de libros segun ew.com
#
# ## ws_book_to_screen_adapt.ipynb
#
# Web scraping anterior realizado en Jupyter para ir comprobando poco a poco que funcionaba. Hubo algún problema con los tiempos de ejecucion. Se cerraba el selenium. Finalmente se utilizó webdriverwait para que no se interrumpiera la ejecución.
#
# ## web_scraping_fed edit_2008_22.ipynb
#
# Webscraping realizado a la web de federación de editores para conseguir los datos estadísticos de españa. Intentaremos contrastar datos, pero será dificil. **No pasado a python**.
#
# ## herramientas.py
#
# la intención de este archivo es ir guardando todas las funciones o código que pueda ser útil para diferentes proyectos. Sería un proyecto de diccionario de sintaxis.
#
# ## merge_amazon.ipynb
#
# Primer intento de merge de las bbdd de amazon. Resultado: no me ha convencido. La bbdd de amazon no me gustó, la he cambiado por otra que indica el formato del libro, porque en la anterior casi seguro que se estaban teniendo en cuenta ebooks también.
# Pendiente de intentar hacer algún merge.
#
# Pte:
#
# Hacer intento de merge entre booksdatasetclean y amazon 100, para ver si conseguimos los años de publicación de los libros y también el género. Este se puede intentar machear con los de kindle.
#
# Análisis Autores más vendidos por año
# Top 5 libros más vendidos por año
#
# Quedarnos con las 5 categorías más representativas
#
# hacer un groupby por género y ver evolución por año
#
#
# ## merge_amazon copy.ipynb
# Aquí están las funciones definitivas de limpieza de las bbdd de amazon. Habría que pasar cada una a su py.
#
# Por el momento en ellas, sobre todo la de kindle, no se hace filtrado de top 100. Primero voy a cruzar con la de amazon a ver si salen más libros iguales. Ahora por lo que sea, si hago el top 100, solo salen iguales 78 libros con audible, por lo tanto, vamos a hacer la prueba.
#
# Tenemos un cruce entre amazon y kindle, kindle y audible, amazon y audible y los tres, kindle, amazon y audible.
#
#  ## booksdataset.ipynb
#  Preparación de base de datos de libros para poder explotarla, separando y recategorizando las categorías de los libros, generando rangos de décadas y limpiando datos varios.
