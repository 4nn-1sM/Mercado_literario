# %%
import pandas as pd
import numpy as np
import os
import shutil

# %%
df_7_bestsell_amazon = pd.read_csv("../data/bestsellers_with_categories_2022_03_27.csv")
df_kindle = pd.read_csv("../data/kindle_data-v2.csv")
df_audible = pd.read_csv("../data/bd_audible_clean.csv")

# %%
ranking = list(range(1,df_7_bestsell_amazon.shape[0]+1))
df_7_bestsell_amazon["Ranking"] = ranking
df_7_bestsell_amazon["title_raw"] = df_7_bestsell_amazon["Name"].str.strip().str.lower().str.replace(":","").str.replace(",","").str.replace(".","")

# %%
years = df_7_bestsell_amazon["Year"].unique()

# %%
# crear un csv por cada año de top ventas
for year in years:
    df_7_bestsell_amazon[df_7_bestsell_amazon["Year"]== year].to_csv("best_sellers_" + str(year) + ".csv")

# %%
df_7_bestsell_amazon["Year"] = years

# %%
df_7_bestsell_amazon["top50_2009"]

# %%
df_7_bestsell_amazon.head(3)
# Out:
#                                                 Name           Author  \
# 0  Act Like a Lady, Think Like a Man: What Men Re...     Steve Harvey
# 1  Arguing with Idiots: How to Stop Small Minds a...       Glenn Beck
# 2          Breaking Dawn (The Twilight Saga, Book 4)  Stephenie Meyer
#
#    User Rating  Reviews  Price  Year        Genre  Ranking  \
# 0          4.6     5013     17  2009  Non Fiction        1
# 1          4.6      798      5  2009  Non Fiction        2
# 2          4.6     9769     13  2009      Fiction        3
#
#                                            title_raw
# 0  act like a lady think like a man what men real...
# 1  arguing with idiots how to stop small minds an...
# 2           breaking dawn (the twilight saga book 4)

# %%
ranking = list(range(1,df_kindle.shape[0]+1))
df_kindle["Ranking"] = ranking
df_kindle["title_raw"] = df_kindle["title"].str.strip().str.lower().str.replace(":","").str.replace(",","").str.replace(".","")

# %%
df_kindle.head(3)
# Out:
#          asin                                              title  \
# 0  B00TZE87S4  Adult Children of Emotionally Immature Parents...
# 1  B08WCKY8MB  From Strength to Strength: Finding Success, Ha...
# 2  B09KPS84CJ  Good Inside: A Guide to Becoming the Parent Yo...
#
#               author                    soldBy  \
# 0  Lindsay C. Gibson   Amazon.com Services LLC
# 1   Arthur C. Brooks   Penguin Group (USA) LLC
# 2      Becky Kennedy  HarperCollins Publishers
#
#                                               imgUrl  \
# 0  https://m.media-amazon.com/images/I/713KZTsaYp...
# 1  https://m.media-amazon.com/images/I/A1LZcJFs9E...
# 2  https://m.media-amazon.com/images/I/71RIWM0sv6...
#
#                              productURL  stars  reviews  price  \
# 0  https://www.amazon.com/dp/B00TZE87S4    4.8        0   9.99
# 1  https://www.amazon.com/dp/B08WCKY8MB    4.4        0  16.99
# 2  https://www.amazon.com/dp/B09KPS84CJ    4.8        0  16.99
#
# ...

# %%
ranking = list(range(1,df_audible.shape[0]+1))
df_audible["Ranking"] = ranking
df_audible["title_raw"] = df_audible["Title"].str.strip().str.lower().str.replace(":","").str.replace(",","").str.replace(".","")

# %%
df_audible.head(3)
# Out:
#    Unnamed: 0                         Title        Categories  \
# 0           0  Learn Arabic Ultimate Bundle  Travel & Tourism
# 1           1          The Impossible First  Travel & Tourism
# 2           2         Buying Disney's World  Travel & Tourism
#
#                              Author        Narrated By Series  Length (Hours)  \
# 0  Global Citizen Language Learning  Mehdi Ben Mahmoud    NaN              13
# 1                     Colin O'Brady      Colin O'Brady    NaN               8
# 2                    Aaron Goldberg  Susan L. Crawford    NaN               4
#
#    Length (Minutes) ReleaseDate  Price Ratings  Overall Rating Out of 5  \
# 0              28.0   12/4/2023  24.95      34                      5.0
# 1              38.0   1/14/2020  18.74    1156                      4.7
# 2              39.0   4/20/2021  14.95     151                      4.5
#
#    Performance Rating out of 5  Story Rating out of 5  Ranking  \
# ...

# %%
df_7_bestsell_amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         700 non-null    object
#  1   Author       700 non-null    object
#  2   User Rating  700 non-null    float64
#  3   Reviews      700 non-null    int64
#  4   Price        700 non-null    int64
#  5   Year         700 non-null    int64
#  6   Genre        700 non-null    object
#  7   Ranking      700 non-null    int64
#  8   title_raw    700 non-null    object
# dtypes: float64(1), int64(4), object(4)
# memory usage: 49.3+ KB

# %%
df_kindle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133102 entries, 0 to 133101
# Data columns (total 18 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   asin               133102 non-null  object
#  1   title              133102 non-null  object
#  2   author             132677 non-null  object
#  3   soldBy             123869 non-null  object
#  4   imgUrl             133102 non-null  object
#  5   productURL         133102 non-null  object
#  6   stars              133102 non-null  float64
#  7   reviews            133102 non-null  int64
#  8   price              133102 non-null  float64
#  9   isKindleUnlimited  133102 non-null  bool
#  10  category_id        133102 non-null  int64
#  11  isBestSeller       133102 non-null  bool
#  12  isEditorsPick      133102 non-null  bool
#  13  isGoodReadsChoice  133102 non-null  bool
#  14  publishedDate      84086 non-null   object
# ...

# %%
df_audible.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2400 entries, 0 to 2399
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   2400 non-null   int64
#  1   Title                        2400 non-null   object
#  2   Categories                   2400 non-null   object
#  3   Author                       2400 non-null   object
#  4   Narrated By                  2391 non-null   object
#  5   Series                       661 non-null    object
#  6   Length (Hours)               2400 non-null   int64
#  7   Length (Minutes)             2351 non-null   float64
#  8   ReleaseDate                  2400 non-null   object
#  9   Price                        2338 non-null   float64
#  10  Ratings                      2400 non-null   object
#  11  Overall Rating Out of 5      2327 non-null   float64
#  12  Performance Rating out of 5  2327 non-null   float64
# ...

# %%
amaz_kind_inn = pd.merge(df_7_bestsell_amazon, df_kindle, how="inner", left_on="Name", right_on="title", suffixes=["_amazon", "_kindle"])
amaz_kind_inn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               366 non-null    object
#  1   Author             366 non-null    object
#  2   User Rating        366 non-null    float64
#  3   Reviews            366 non-null    int64
#  4   Price              366 non-null    int64
#  5   Year               366 non-null    int64
#  6   Genre              366 non-null    object
#  7   Ranking_amazon     366 non-null    int64
#  8   title_raw_amazon   366 non-null    object
#  9   asin               366 non-null    object
#  10  title              366 non-null    object
#  11  author             366 non-null    object
#  12  soldBy             271 non-null    object
#  13  imgUrl             366 non-null    object
#  14  productURL         366 non-null    object
#  15  stars              366 non-null    float64
# ...

# %%
kind_audib = pd.merge(df_kindle, df_audible, how="inner", left_on="title", right_on="Title", suffixes=["_amazon", "_kindle"])
kind_audib.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382 entries, 0 to 381
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   asin                         382 non-null    object
#  1   title                        382 non-null    object
#  2   author                       382 non-null    object
#  3   soldBy                       308 non-null    object
#  4   imgUrl                       382 non-null    object
#  5   productURL                   382 non-null    object
#  6   stars                        382 non-null    float64
#  7   reviews                      382 non-null    int64
#  8   price                        382 non-null    float64
#  9   isKindleUnlimited            382 non-null    bool
#  10  category_id                  382 non-null    int64
#  11  isBestSeller                 382 non-null    bool
#  12  isEditorsPick                382 non-null    bool
# ...

# %%
amaz_audib = pd.merge(df_7_bestsell_amazon, df_audible, how="inner", left_on="Name", right_on="Title", suffixes=["_amazon", "_kindle"])
amaz_audib.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name                         77 non-null     object
#  1   Author_amazon                77 non-null     object
#  2   User Rating                  77 non-null     float64
#  3   Reviews                      77 non-null     int64
#  4   Price_amazon                 77 non-null     int64
#  5   Year                         77 non-null     int64
#  6   Genre                        77 non-null     object
#  7   Ranking_amazon               77 non-null     int64
#  8   title_raw_amazon             77 non-null     object
#  9   Unnamed: 0                   77 non-null     int64
#  10  Title                        77 non-null     object
#  11  Categories                   77 non-null     object
#  12  Author_kindle                77 non-null     object
# ...

# %%
amaz_kind_audib = pd.merge(amaz_kind_inn, df_audible, how="inner", left_on="Name", right_on="Title", suffixes=["_amazon", "_audible"])
amaz_kind_audib.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name                         60 non-null     object
#  1   Author_amazon                60 non-null     object
#  2   User Rating                  60 non-null     float64
#  3   Reviews                      60 non-null     int64
#  4   Price_amazon                 60 non-null     int64
#  5   Year                         60 non-null     int64
#  6   Genre                        60 non-null     object
#  7   Ranking_amazon               60 non-null     int64
#  8   title_raw_amazon             60 non-null     object
#  9   asin                         60 non-null     object
#  10  title                        60 non-null     object
#  11  author                       60 non-null     object
#  12  soldBy                       46 non-null     object
# ...

# %%
amaz_kind_audib.head(1)
# Out:
#    Name   Author_amazon  User Rating  Reviews  Price_amazon  Year  \
# 0  Life  Keith Richards          4.5     2752            18  2010
#
#          Genre  Ranking_amazon title_raw_amazon        asin  ...  \
# 0  Non Fiction              66             life  B003UBTX72  ...
#
#   Length (Hours) Length (Minutes) ReleaseDate Price_audible Ratings  \
# 0             23              5.0  10/26/2010         35.09    5683
#
#    Overall Rating Out of 5  Performance Rating out of 5  \
# 0                      4.3                          4.4
#
#    Story Rating out of 5  Ranking  title_raw
# 0                    4.4     2340       life
#
# [1 rows x 43 columns]

# %%
amaz_kind_inn2 = pd.merge(df_7_bestsell_amazon, df_kindle, how="inner", left_on="title_raw", right_on="title_raw", suffixes=["_amazon", "_kindle"])
amaz_kind_inn2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384 entries, 0 to 383
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               384 non-null    object
#  1   Author             384 non-null    object
#  2   User Rating        384 non-null    float64
#  3   Reviews            384 non-null    int64
#  4   Price              384 non-null    int64
#  5   Year               384 non-null    int64
#  6   Genre              384 non-null    object
#  7   Ranking_amazon     384 non-null    int64
#  8   title_raw          384 non-null    object
#  9   asin               384 non-null    object
#  10  title              384 non-null    object
#  11  author             384 non-null    object
#  12  soldBy             279 non-null    object
#  13  imgUrl             384 non-null    object
#  14  productURL         384 non-null    object
#  15  stars              384 non-null    float64
# ...

# %%
kind_audib = pd.merge(df_kindle, df_audible, how="inner", left_on="title_raw", right_on="title_raw", suffixes=["_kindle", "_audible"])
kind_audib.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   asin                         395 non-null    object
#  1   title                        395 non-null    object
#  2   author                       395 non-null    object
#  3   soldBy                       321 non-null    object
#  4   imgUrl                       395 non-null    object
#  5   productURL                   395 non-null    object
#  6   stars                        395 non-null    float64
#  7   reviews                      395 non-null    int64
#  8   price                        395 non-null    float64
#  9   isKindleUnlimited            395 non-null    bool
#  10  category_id                  395 non-null    int64
#  11  isBestSeller                 395 non-null    bool
#  12  isEditorsPick                395 non-null    bool
# ...

# %%
amaz_audib = pd.merge(df_7_bestsell_amazon, df_audible, how="inner", left_on="title_raw", right_on="title_raw", suffixes=["_amazon", "_audible"])
amaz_audib.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name                         77 non-null     object
#  1   Author_amazon                77 non-null     object
#  2   User Rating                  77 non-null     float64
#  3   Reviews                      77 non-null     int64
#  4   Price_amazon                 77 non-null     int64
#  5   Year                         77 non-null     int64
#  6   Genre                        77 non-null     object
#  7   Ranking_amazon               77 non-null     int64
#  8   title_raw                    77 non-null     object
#  9   Unnamed: 0                   77 non-null     int64
#  10  Title                        77 non-null     object
#  11  Categories                   77 non-null     object
#  12  Author_audible               77 non-null     object
# ...

# %%
amaz_kind_audib = pd.merge(amaz_kind_inn2, df_audible, how="inner", left_on="title_raw", right_on="title_raw", suffixes=["_amazon", "_kindle"])
amaz_kind_audib.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 41 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name                         60 non-null     object
#  1   Author_amazon                60 non-null     object
#  2   User Rating                  60 non-null     float64
#  3   Reviews                      60 non-null     int64
#  4   Price_amazon                 60 non-null     int64
#  5   Year                         60 non-null     int64
#  6   Genre                        60 non-null     object
#  7   Ranking_amazon               60 non-null     int64
#  8   title_raw                    60 non-null     object
#  9   asin                         60 non-null     object
#  10  title                        60 non-null     object
#  11  author                       60 non-null     object
#  12  soldBy                       46 non-null     object
# ...

# %%
amaz_kind_audib["Name"].value_counts()
# Out:
# Name
# Thinking, Fast and Slow                 8
# Becoming                                6
# Where the Crawdads Sing                 6
# Wonder                                  5
# Greenlights                             4
# The Book Thief                          4
# Untamed                                 4
# Born to Run                             4
# A Promised Land                         3
# The Immortal Life of Henrietta Lacks    3
# Steve Jobs                              2
# Verity                                  2
# The Silent Patient                      2
# The Wright Brothers                     2
# Life                                    1
# When Breath Becomes Air                 1
# Alexander Hamilton                      1
# The Alchemist                           1
# We Were Liars                           1
# Name: count, dtype: int64

# %%
amaz_kind_audib.columns
# Out:
# Index(['Name', 'Author_amazon', 'User Rating', 'Reviews', 'Price_amazon',
#        'Year', 'Genre', 'Ranking_amazon', 'title_raw', 'asin', 'title',
#        'author', 'soldBy', 'imgUrl', 'productURL', 'stars', 'reviews', 'price',
#        'isKindleUnlimited', 'category_id', 'isBestSeller', 'isEditorsPick',
#        'isGoodReadsChoice', 'publishedDate', 'category_name', 'Ranking_kindle',
#        'Unnamed: 0', 'Title', 'Categories', 'Author_kindle', 'Narrated By',
#        'Series', 'Length (Hours)', 'Length (Minutes)', 'ReleaseDate',
#        'Price_kindle', 'Ratings', 'Overall Rating Out of 5',
#        'Performance Rating out of 5', 'Story Rating out of 5', 'Ranking'],
#       dtype='object')

# %%
amaz_kind_audib.loc[:,["Name",'title','Title', "Author_amazon",'author','Author_kindle','Genre','category_name','Categories']]
# Out:
#                                     Name  \
# 0                                   Life
# 1   The Immortal Life of Henrietta Lacks
# 2                             Steve Jobs
# 3   The Immortal Life of Henrietta Lacks
# 4                Thinking, Fast and Slow
# 5                Thinking, Fast and Slow
# 6                Thinking, Fast and Slow
# 7                Thinking, Fast and Slow
# 8                             Steve Jobs
# 9   The Immortal Life of Henrietta Lacks
# 10               Thinking, Fast and Slow
# 11               Thinking, Fast and Slow
# 12               Thinking, Fast and Slow
# 13               Thinking, Fast and Slow
# 14                        The Book Thief
# 15                        The Book Thief
# 16                                Wonder
# 17                         The Alchemist
# 18                        The Book Thief
# 19                        The Book Thief
# 20                                Wonder
# 21                   The Wright Brothers
# ...
