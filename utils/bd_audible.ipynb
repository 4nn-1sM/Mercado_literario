# %%
import pandas as pd
import numpy as np

# %%
df_4_audible = pd.DataFrame(pd.read_csv("../data/Audible_Top_100_Final.csv", encoding='windows-1252'))
df_4_audible.head()
# Out:
#                           Title        Categories  \
# 0  Learn Arabic Ultimate Bundle  Travel & Tourism
# 1          The Impossible First  Travel & Tourism
# 2         Buying Disney's World  Travel & Tourism
# 3     Learn Spanish in Your Car  Travel & Tourism
# 4        For the Love of Europe  Travel & Tourism
#
#                              Author        Narrated By Series  Length (Hours)  \
# 0  Global Citizen Language Learning  Mehdi Ben Mahmoud    NaN              13
# 1                     Colin O'Brady      Colin O'Brady    NaN               8
# 2                    Aaron Goldberg  Susan L. Crawford    NaN               4
# 3                      Glenda Greco          Shea Jean    NaN              10
# 4                       Rick Steves        Rick Steves    NaN              10
#
#    Length (Minutes) ReleaseDate  Price Ratings  ...  \
# 0              28.0   12/4/2023  24.95      34  ...
# 1              38.0   1/14/2020  18.74    1156  ...
# ...

# %%
df_4_audible.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2400 entries, 0 to 2399
# Data columns (total 44 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Title                        2400 non-null   object
#  1   Categories                   2400 non-null   object
#  2   Author                       2400 non-null   object
#  3   Narrated By                  2391 non-null   object
#  4   Series                       661 non-null    object
#  5   Length (Hours)               2400 non-null   int64
#  6   Length (Minutes)             2351 non-null   float64
#  7   ReleaseDate                  2400 non-null   object
#  8   Price                        2338 non-null   float64
#  9   Ratings                      2400 non-null   object
#  10  Overall Rating Out of 5      2327 non-null   float64
#  11  Performance Rating out of 5  2327 non-null   float64
#  12  Story Rating out of 5        2327 non-null   float64
# ...

# %%
# eliminación de columnas en las que todos los valores son nulos
df_4_audible = df_4_audible.dropna(how="all", axis= 1)

# %%
df_4_audible.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2400 entries, 0 to 2399
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Title                        2400 non-null   object
#  1   Categories                   2400 non-null   object
#  2   Author                       2400 non-null   object
#  3   Narrated By                  2391 non-null   object
#  4   Series                       661 non-null    object
#  5   Length (Hours)               2400 non-null   int64
#  6   Length (Minutes)             2351 non-null   float64
#  7   ReleaseDate                  2400 non-null   object
#  8   Price                        2338 non-null   float64
#  9   Ratings                      2400 non-null   object
#  10  Overall Rating Out of 5      2327 non-null   float64
#  11  Performance Rating out of 5  2327 non-null   float64
#  12  Story Rating out of 5        2327 non-null   float64
# ...

# %%
# eliminación de las columnas que son los textos de las 3 primeras reviews.
df_4_audible = df_4_audible.iloc[:,:-9].copy()

# %%
df_4_audible.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2400 entries, 0 to 2399
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Title                        2400 non-null   object
#  1   Categories                   2400 non-null   object
#  2   Author                       2400 non-null   object
#  3   Narrated By                  2391 non-null   object
#  4   Series                       661 non-null    object
#  5   Length (Hours)               2400 non-null   int64
#  6   Length (Minutes)             2351 non-null   float64
#  7   ReleaseDate                  2400 non-null   object
#  8   Price                        2338 non-null   float64
#  9   Ratings                      2400 non-null   object
#  10  Overall Rating Out of 5      2327 non-null   float64
#  11  Performance Rating out of 5  2327 non-null   float64
#  12  Story Rating out of 5        2327 non-null   float64
# ...

# %%
df_4_audible.value_counts("Categories")
# Out:
# Categories
# Arts & Entertainment                               100
# Biographies & Memoirs                              100
# Business & Careers                                 100
# Children's Audiobooks                              100
# Comedy & Humor                                     100
# Computers & Technology                             100
# Education & Learning                               100
# Erotica                                            100
# Health & Wellness                                  100
# History                                            100
# Home & Garden                                      100
# LGBTQ+                                             100
# Literature & Fiction                               100
# Money & Finance                                    100
# Mystery, Thriller & Suspense                       100
# Politics & Social Sciences                         100
# Relationships, Parenting & Personal Development    100
# ...

# %%
# creacion de df con las columnas más apropiadas para análisis
df_audible = df_4_audible.iloc[:,0:13].copy()
df_audible
# Out:
#                                                   Title            Categories  \
# 0                          Learn Arabic Ultimate Bundle      Travel & Tourism
# 1                                  The Impossible First      Travel & Tourism
# 2                                 Buying Disney's World      Travel & Tourism
# 3                             Learn Spanish in Your Car      Travel & Tourism
# 4                                For the Love of Europe      Travel & Tourism
# ...                                                 ...                   ...
# 2395                                       Born a Crime  Arts & Entertainment
# 2396                                   The Creative Act  Arts & Entertainment
# 2397        Friends, Lovers, and the Big Terrible Thing  Arts & Entertainment
# 2398  Fourth Wing (Part 2 of 2) (Dramatized Adaptation)  Arts & Entertainment
# 2399                           Third Girl from the Left  Arts & Entertainment
#
# ...

# %%
# para guardar la tabla anterior en csv
df_audible.to_csv("../data/a_audible100.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # para guardar la tabla anterior en csv
# ----> 2 df_audible.to_csv("../data/a_audible100.csv")
#
# NameError: name 'df_audible' is not defined
